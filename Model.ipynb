# %%
#ps - When we exercise, we need energy from food. Thus we use more oxygen to break down glucose molecules and energy is released. Part of energy is utilized and part is heat energy. To cool down the body head, we release sweat. This is the process of calories burning. Therefore, considering all the important parameters, I have developed a model to predict how many calories are burnt.
#step 1 - dataset
#step 2 - Data preprocessing
#step 3 - data analysis
#step 4 - train test split
#step 5 - XGBoost Regressor model training
#step 6 - evaluation

# %%
#STEP 1: Dataset

#importing the dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
import sys
# !{sys.executable} -m pip install xgboost
# Out:
# ...
#   Using cached xgboost-1.7.3-py3-none-win_amd64.whl (89.1 MB)
# ...

# %%
from xgboost import XGBRegressor

# %%
#importing dataset
calories = pd.read_csv(r"./calories.csv")

# %%
calories
# Out:
#         User_ID  Calories
# 0      14733363     231.0
# 1      14861698      66.0
# 2      11179863      26.0
# 3      16180408      71.0
# 4      17771927      35.0
# ...         ...       ...
# 14995  15644082      45.0
# 14996  17212577      23.0
# 14997  17271188      75.0
# 14998  18643037      11.0
# 14999  11751526      98.0
#
# [15000 rows x 2 columns]

# %%
exercise_data = pd.read_csv(r"./exercise.csv")

# %%
exercise_data
# Out:
#         User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp
# 0      14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1      14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2      11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3      16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4      17771927  female   27   154.0    58.0      10.0        81.0       39.8
# ...         ...     ...  ...     ...     ...       ...         ...        ...
# 14995  15644082  female   20   193.0    86.0      11.0        92.0       40.4
# 14996  17212577  female   27   165.0    65.0       6.0        85.0       39.2
# 14997  17271188  female   43   159.0    58.0      16.0        90.0       40.1
# 14998  18643037    male   78   193.0    97.0       2.0        84.0       38.3
# 14999  11751526    male   63   173.0    79.0      18.0        92.0       40.5
#
# [15000 rows x 8 columns]

# %%
#combining the two dataframes
calories_data = pd.concat([exercise_data, calories['Calories']],axis=1)

# %%
calories_data
# Out:
#         User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0      14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1      14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2      11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3      16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4      17771927  female   27   154.0    58.0      10.0        81.0       39.8
# ...         ...     ...  ...     ...     ...       ...         ...        ...
# 14995  15644082  female   20   193.0    86.0      11.0        92.0       40.4
# 14996  17212577  female   27   165.0    65.0       6.0        85.0       39.2
# 14997  17271188  female   43   159.0    58.0      16.0        90.0       40.1
# 14998  18643037    male   78   193.0    97.0       2.0        84.0       38.3
# 14999  11751526    male   63   173.0    79.0      18.0        92.0       40.5
#
#        Calories
# ...

# %%
calories_data.shape
# Out:
# (15000, 9)
